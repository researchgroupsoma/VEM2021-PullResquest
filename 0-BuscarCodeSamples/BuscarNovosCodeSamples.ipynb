# %%
pip install PyGithub
# Out:
# ...
#      |████████████████████████████████| 296kB 6.9MB/s
# ...
#      |████████████████████████████████| 962kB 9.5MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Faculdade/Mestrado/Artigos/VEM2021-Matheus/0-BuscarCodeSamples
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Faculdade/Mestrado/Artigos/VEM2021-Matheus/0-BuscarCodeSamples'
# /content/drive/MyDrive/Faculdade/Mestrado/Artigos/VEM2021-Matheus/0-BuscarCodeSamples

# %%
from github import Github
g = Github("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")
import pandas as pd

# %%
def get_code_samples(organization):
  org = g.get_organization(organization)
  repos = []
  for repo in org.get_repos("public"):
    repos.append(repo.full_name)
  dataframe = pd.DataFrame(repos)
  dataframe.to_csv(f"{organization}.csv", header=False, index=False)

# %%
get_code_samples("googlesamples")

# %% [markdown]
# Google Archive is manually extract by:
# - https://github.com/googlearchive?q=sample&type=&language=&sort=
# - https://github.com/googlearchive?q=migrated&type=&language=&sort=

# %%
# get_code_samples("googlearchive")

# %%
get_code_samples("spring-guides")

# %%
get_code_samples("aws-samples")

# %%
get_code_samples("Azure-Samples")

# %%
get_code_samples("spring-cloud-samples")
