# %%
pip install PyGithub
# Out:
# Requirement already satisfied: PyGithub in /usr/local/lib/python3.7/dist-packages (1.55)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.7/dist-packages (from PyGithub) (2.23.0)
# Requirement already satisfied: pynacl>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from PyGithub) (1.4.0)
# Requirement already satisfied: pyjwt>=2.0 in /usr/local/lib/python3.7/dist-packages (from PyGithub) (2.1.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.7/dist-packages (from PyGithub) (1.2.12)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from pynacl>=1.4.0->PyGithub) (1.15.0)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from pynacl>=1.4.0->PyGithub) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->PyGithub) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->PyGithub) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->PyGithub) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->PyGithub) (1.24.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated->PyGithub) (1.12.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/VEM2021-Matheus")

# %%
from github import Github
from datetime import datetime
g = Github("Chave")
import pandas as pd

# %%
def getAllPullRequests(sample):
  repo = g.get_repo(sample)
  print(sample)
  pulls = []
  for pull in repo.get_pulls(state = 'all'):
    pulls.append(pull)
  return pulls

# %%
def getDataframe(dataframe, framework, sample, pulls):
  return dataframe.append(other=[
                              {
                                "framework" : framework,
                                "sample": sample,
                                "link": pull.html_url,
                                "data de criação": pull.created_at,
                                "data de fechamento": pull.closed_at,
                                "tempo para fechamento": (pull.closed_at - pull.created_at).days if pull.closed_at != '' and pull.closed_at is not None else "",
                                "tempo merge": (pull.merged_at - pull.created_at).days   if pull.merged == True and pull.merged_at is not None else "",
                                "data merge": pull.merged_at,
                                "data de atualização": pull.updated_at,
                                "merged": pull.merged,
                                "titulo": pull.title,
                                "status": pull.state,
                                "merge user cargo": pull.merged_by.role if pull.merged == True and pull.merged_by is not None else "",
                                "merge user empresa": pull.merged_by.company if pull.merged == True and pull.merged_by is not None else "",  
                                "merge user local": pull.merged_by.location if pull.merged == True and pull.merged_by is not None else "", 
                                "merge user login": pull.merged_by.login if pull.merged == True and pull.merged_by is not None else "",
                                "merge user email": pull.merged_by.email if pull.merged == True and pull.merged_by is not None else "",
                                "merge user seguidores": pull.merged_by.followers if pull.merged == True and pull.merged_by is not None else "",
                                "merge user tempo no GitHub":  (pull.merged_at - pull.merged_by.created_at).days if pull.merged == True and pull.merged_by is not None else ""
                                } for pull in pulls])

# %%
def export(dataframe):
  dataframe.to_csv("1-ExtrairDadosDePR/googlearchive.csv")

# %%
def main():
  samples = pd.read_csv("0-BuscarCodeSamples/googlearchive.csv", names=["sample"])
  dataframe = pd.DataFrame(columns=["framework","sample","link","data de criação","data de fechamento"
                                  ,"tempo para fechamento","tempo merge","data merge","data de atualização",
                                  "merged","titulo","status", "merge user cargo","merge user empresa",
                                  "merge user local", "merge user login","merge user email","merge user seguidores",
                                  "merge user tempo no GitHub"])
  for sample in samples["sample"]:
    framework = sample.split("/")
    framework = framework[0]
    pulls = getAllPullRequests(sample)
    dataframe = getDataframe(dataframe, framework, sample, pulls)

  export(dataframe) 
  
if __name__ == "__main__":
    main()
# Out:
# googlearchive/actionssdk-eliza-nodejs
# googlearchive/actionssdk-eliza-nodejs
# googlearchive/android-AccelerometerPlay
# googlearchive/android-AccelerometerPlay
# googlearchive/android-ActionBarCompat-Basic
# googlearchive/android-ActionBarCompat-Basic
# googlearchive/android-ActionBarCompat-ListPopupMenu
# googlearchive/android-ActionBarCompat-ListPopupMenu
# googlearchive/android-ActionBarCompat-ShareActionProvider
# googlearchive/android-ActionBarCompat-ShareActionProvider
# googlearchive/android-ActionBarCompat-Styled
# googlearchive/android-ActionBarCompat-Styled
# googlearchive/android-ActiveNotifications
# googlearchive/android-ActiveNotifications
# googlearchive/android-ActivityInstrumentation
# googlearchive/android-ActivityInstrumentation
# googlearchive/android-ActivitySceneTransitionBasic
# googlearchive/android-ActivitySceneTransitionBasic
# googlearchive/android-ads
# googlearchive/android-ads
# googlearchive/android-AdvancedImmersiveMode
# googlearchive/android-AdvancedImmersiveMode
# googlearchive/android-AlwaysOn
# googlearchive/android-AlwaysOn
# googlearchive/android-AppRestrictionEnforcer
# googlearchive/android-AppRestrictionEnforcer
# googlearchive/android-AppRestrictions
# googlearchive/android-AppRestrictions
# googlearchive/android-AppRestrictionSchema
# googlearchive/android-AppRestrictionSchema
# googlearchive/android-AppShortcuts
# googlearchive/android-AppShortcuts
# googlearchive/android-AsymmetricFingerprintDialog
# googlearchive/android-AsymmetricFingerprintDialog
# googlearchive/android-AutoBackupForApps
# googlearchive/android-AutoBackupForApps
# googlearchive/android-AutofillFramework
# googlearchive/android-AutofillFramework
# googlearchive/android-BasicAndroidKeyStore
# googlearchive/android-BasicAndroidKeyStore
# googlearchive/android-BasicContactables
# googlearchive/android-BasicContactables
# googlearchive/android-BasicGestureDetect
# googlearchive/android-BasicGestureDetect
# googlearchive/android-BasicImmersiveMode
# googlearchive/android-BasicImmersiveMode
# googlearchive/android-BasicManagedProfile
# googlearchive/android-BasicManagedProfile
# googlearchive/android-BasicMediaDecoder
# googlearchive/android-BasicMediaDecoder
# googlearchive/android-BasicMediaRouter
# googlearchive/android-BasicMediaRouter
# googlearchive/android-BasicMultitouch
# googlearchive/android-BasicMultitouch
# googlearchive/android-BasicNetworking
# googlearchive/android-BasicNetworking
# googlearchive/android-BasicNotifications
# googlearchive/android-BasicNotifications
# googlearchive/android-BasicRenderScript
# googlearchive/android-BasicRenderScript
# googlearchive/android-BasicSyncAdapter
# googlearchive/android-BasicSyncAdapter
# googlearchive/android-BasicTransition
# googlearchive/android-BasicTransition
# googlearchive/android-BatchStepSensor
# googlearchive/android-BatchStepSensor
# googlearchive/android-BeamLargeFiles
# googlearchive/android-BeamLargeFiles
# googlearchive/android-BluetoothAdvertisements
# googlearchive/android-BluetoothAdvertisements
# googlearchive/android-BluetoothChat
# googlearchive/android-BluetoothChat
# googlearchive/android-BluetoothLeGatt
# googlearchive/android-BluetoothLeGatt
# googlearchive/android-BorderlessButtons
# googlearchive/android-BorderlessButtons
# googlearchive/android-Bubbles
# googlearchive/android-Bubbles
# googlearchive/android-Camera2Basic
# googlearchive/android-Camera2Basic
# googlearchive/android-Camera2Raw
# googlearchive/android-Camera2Raw
# googlearchive/android-Camera2Video
# googlearchive/android-Camera2Video
# googlearchive/android-CardEmulation
# googlearchive/android-CardEmulation
# googlearchive/android-CardReader
# googlearchive/android-CardReader
# googlearchive/android-CardView
# googlearchive/android-CardView
# googlearchive/android-ClippingBasic
# googlearchive/android-ClippingBasic
# googlearchive/android-CommitContentSampleApp
# googlearchive/android-CommitContentSampleApp
# googlearchive/android-CommitContentSampleIME
# googlearchive/android-CommitContentSampleIME
# googlearchive/android-ConfirmCredential
# googlearchive/android-ConfirmCredential
# googlearchive/android-constraint-layout-performance
# googlearchive/android-constraint-layout-performance
# googlearchive/android-ConstraintLayoutExamples
# googlearchive/android-ConstraintLayoutExamples
# googlearchive/android-ContentProviderPaging
# googlearchive/android-ContentProviderPaging
# googlearchive/android-credentials
# googlearchive/android-credentials
# googlearchive/android-CustomChoiceList
# googlearchive/android-CustomChoiceList
# googlearchive/android-CustomNotifications
# googlearchive/android-CustomNotifications
# googlearchive/android-CustomTransition
# googlearchive/android-CustomTransition
# googlearchive/android-DarkTheme
# googlearchive/android-DarkTheme
# googlearchive/android-DataLayer
# googlearchive/android-DataLayer
# googlearchive/android-DeviceOwner
# googlearchive/android-DeviceOwner
# googlearchive/android-DirectBoot
# googlearchive/android-DirectBoot
# googlearchive/android-DirectShare
# googlearchive/android-DirectShare
# googlearchive/android-DisplayingBitmaps
# googlearchive/android-DisplayingBitmaps
# googlearchive/android-DocumentCentricApps
# googlearchive/android-DocumentCentricApps
# googlearchive/android-DocumentCentricRelinquishIdentity
# googlearchive/android-DocumentCentricRelinquishIdentity
# googlearchive/android-DoneBar
# googlearchive/android-DoneBar
# googlearchive/android-DownloadableFonts
# googlearchive/android-DownloadableFonts
# googlearchive/android-DragAndDropAcrossApps
# googlearchive/android-DragAndDropAcrossApps
# googlearchive/android-DrawableTinting
# googlearchive/android-DrawableTinting
# googlearchive/android-dynamic-features
# googlearchive/android-dynamic-features
# googlearchive/android-ElevationBasic
# googlearchive/android-ElevationBasic
# googlearchive/android-ElevationDrag
# googlearchive/android-ElevationDrag
# googlearchive/android-EmojiCompat
# googlearchive/android-EmojiCompat
# googlearchive/android-fido
# googlearchive/android-fido
# googlearchive/android-FingerprintDialog
# googlearchive/android-FingerprintDialog
# googlearchive/android-fit
# googlearchive/android-fit
# googlearchive/android-fit-xamarin
# googlearchive/android-fit-xamarin
# googlearchive/android-FloatingActionButtonBasic
# googlearchive/android-FloatingActionButtonBasic
# googlearchive/android-gcmnetworkmanager
# googlearchive/android-gcmnetworkmanager
# googlearchive/android-google-accounts
# googlearchive/android-google-accounts
# googlearchive/android-HdrViewfinder
# googlearchive/android-HdrViewfinder
# googlearchive/android-HorizontalPaging
# googlearchive/android-HorizontalPaging
# googlearchive/android-ImmersiveMode
# googlearchive/android-ImmersiveMode
# googlearchive/android-instant-apps
# googlearchive/android-instant-apps
# googlearchive/android-InteractiveSliceProvider
# googlearchive/android-InteractiveSliceProvider
# googlearchive/android-Interpolator
# googlearchive/android-Interpolator
# googlearchive/android-JobScheduler
# googlearchive/android-JobScheduler
# googlearchive/android-JumpingJack
# googlearchive/android-JumpingJack
# googlearchive/android-LNotifications
# googlearchive/android-LNotifications
# googlearchive/android-MediaBrowserService
# googlearchive/android-MediaBrowserService
# googlearchive/android-MediaEffects
# googlearchive/android-MediaEffects
# googlearchive/android-MediaRecorder
# googlearchive/android-MediaRecorder
# googlearchive/android-MediaRouter
# googlearchive/android-MediaRouter
# googlearchive/android-MessagingService
# googlearchive/android-MessagingService
# googlearchive/android-MidiScope
# googlearchive/android-MidiScope
# googlearchive/android-MidiSynth
# googlearchive/android-MidiSynth
# googlearchive/android-MultiWindowPlayground
# googlearchive/android-MultiWindowPlayground
# googlearchive/android-NavigationDrawer
# googlearchive/android-NavigationDrawer
# googlearchive/android-nearby
# googlearchive/android-nearby
# googlearchive/android-nearby-cpp
# googlearchive/android-nearby-cpp
# googlearchive/android-NetworkConnect
# googlearchive/android-NetworkConnect
# googlearchive/android-NfcProvisioning
# googlearchive/android-NfcProvisioning
# googlearchive/android-NotificationChannels
# googlearchive/android-NotificationChannels
# googlearchive/android-Notifications
# googlearchive/android-Notifications
# googlearchive/android-OurStreets
# googlearchive/android-OurStreets
# googlearchive/android-PdfRendererBasic
# googlearchive/android-PdfRendererBasic
# googlearchive/android-PictureInPicture
# googlearchive/android-PictureInPicture
# googlearchive/android-play-awareness
# googlearchive/android-play-awareness
# googlearchive/android-preferences
# googlearchive/android-preferences
# googlearchive/android-RecyclerView
# googlearchive/android-RecyclerView
# googlearchive/android-RenderScriptIntrinsic
# googlearchive/android-RenderScriptIntrinsic
# googlearchive/android-RepeatingAlarm
# googlearchive/android-RepeatingAlarm
# googlearchive/android-RevealEffectBasic
# googlearchive/android-RevealEffectBasic
# googlearchive/android-RuntimePermissions
# googlearchive/android-RuntimePermissions
# googlearchive/android-RuntimePermissionsBasic
# googlearchive/android-RuntimePermissionsBasic
# googlearchive/android-RuntimePermissionsWear
# googlearchive/android-RuntimePermissionsWear
# googlearchive/android-ScopedDirectoryAccess
# googlearchive/android-ScopedDirectoryAccess
# googlearchive/android-ScreenCapture
# googlearchive/android-ScreenCapture
# googlearchive/android-ShareActionProvider
# googlearchive/android-ShareActionProvider
# googlearchive/android-SharingShortcuts
# googlearchive/android-SharingShortcuts
# googlearchive/android-SimpleMediaPlayer
# googlearchive/android-SimpleMediaPlayer
# googlearchive/android-SliceViewer
# googlearchive/android-SliceViewer
# googlearchive/android-SlidingTabsBasic
# googlearchive/android-SlidingTabsBasic
# googlearchive/android-SlidingTabsColors
# googlearchive/android-SlidingTabsColors
# googlearchive/android-SpeedTracker
# googlearchive/android-SpeedTracker
# googlearchive/android-StorageClient
# googlearchive/android-StorageClient
# googlearchive/android-StorageProvider
# googlearchive/android-StorageProvider
# googlearchive/android-SwipeRefreshLayoutBasic
# googlearchive/android-SwipeRefreshLayoutBasic
# googlearchive/android-SwipeRefreshListFragment
# googlearchive/android-SwipeRefreshListFragment
# googlearchive/android-SwipeRefreshMultipleViews
# googlearchive/android-SwipeRefreshMultipleViews
# googlearchive/android-SynchronizedNotifications
# googlearchive/android-SynchronizedNotifications
# googlearchive/android-text
# googlearchive/android-text
# googlearchive/android-TextLinkify
# googlearchive/android-TextLinkify
# googlearchive/android-TextSwitcher
# googlearchive/android-TextSwitcher
# googlearchive/android-transition-examples
# googlearchive/android-transition-examples
# googlearchive/android-ui-toolkit-demos
# googlearchive/android-ui-toolkit-demos
# googlearchive/android-VideoPlayer
# googlearchive/android-VideoPlayer
# googlearchive/android-viewpager2
# googlearchive/android-viewpager2
# googlearchive/android-WatchFace
# googlearchive/android-WatchFace
# googlearchive/android-WclDemoSample
# googlearchive/android-WclDemoSample
# googlearchive/android-wear-xamarin-watchface
# googlearchive/android-wear-xamarin-watchface
# googlearchive/android-WearAccessibilityApp
# googlearchive/android-WearAccessibilityApp
# googlearchive/android-WearCompanionLibrary
# googlearchive/android-WearCompanionLibrary
# googlearchive/android-WearComplicationProvidersTestSuite
# googlearchive/android-WearComplicationProvidersTestSuite
# googlearchive/android-WearDrawers
# googlearchive/android-WearDrawers
# googlearchive/android-WearHighBandwidthNetworking
# googlearchive/android-WearHighBandwidthNetworking
# googlearchive/android-WearOAuth
# googlearchive/android-WearOAuth
# googlearchive/android-WearSpeakerSample
# googlearchive/android-WearSpeakerSample
# googlearchive/android-WearStandaloneGoogleSignIn
# googlearchive/android-WearStandaloneGoogleSignIn
# googlearchive/android-WearVerifyRemoteApp
# googlearchive/android-WearVerifyRemoteApp
# googlearchive/android-WifiRttScan
# googlearchive/android-WifiRttScan
# googlearchive/android-XYZTouristAttractions
# googlearchive/android-XYZTouristAttractions
# googlearchive/androidtv-daydream
# googlearchive/androidtv-daydream
# googlearchive/androidtv-GameController
# googlearchive/androidtv-GameController
# googlearchive/androidtv-Leanback
# googlearchive/androidtv-Leanback
# googlearchive/androidtv-VisualGameController
# googlearchive/androidtv-VisualGameController
# googlearchive/appengine-angular-guestbook-java
# googlearchive/appengine-angular-guestbook-java
# googlearchive/appengine-crowdguru-python
# googlearchive/appengine-crowdguru-python
# googlearchive/appengine-endpoints-helloendpoints-android
# googlearchive/appengine-endpoints-helloendpoints-android
# googlearchive/appengine-gofortwilio
# googlearchive/appengine-gofortwilio
# googlearchive/appengine-i18n-sample-python
# googlearchive/appengine-i18n-sample-python
# googlearchive/appengine-recover-unapplied-writes-python
# googlearchive/appengine-recover-unapplied-writes-python
# googlearchive/appengine-sqlite-guestbook-python
# googlearchive/appengine-sqlite-guestbook-python
# googlearchive/appengine-try-python-webapp2
# googlearchive/appengine-try-python-webapp2
# googlearchive/apps-script-mobile-addons
# googlearchive/apps-script-mobile-addons
# googlearchive/attendee-checkin
# googlearchive/attendee-checkin
# googlearchive/bigquery-appengine-datastore-import-sample
# googlearchive/bigquery-appengine-datastore-import-sample
# googlearchive/bigquery-samples-java
# googlearchive/bigquery-samples-java
# googlearchive/bigquery-samples-python
# googlearchive/bigquery-samples-python
# googlearchive/chromeos-android-draganddrop-demo
# googlearchive/chromeos-android-draganddrop-demo
# googlearchive/chromium-webview-samples
# googlearchive/chromium-webview-samples
# googlearchive/cloud-debugger-gce-java-sample
# googlearchive/cloud-debugger-gce-java-sample
# googlearchive/cloud-pubsub-samples-java
# googlearchive/cloud-pubsub-samples-java
# googlearchive/compute-getting-started-android
# googlearchive/compute-getting-started-android
# googlearchive/compute-getting-started-java
# googlearchive/compute-getting-started-java
# googlearchive/compute-getting-started-python
# googlearchive/compute-getting-started-python
# googlearchive/core-sampler
# googlearchive/core-sampler
# googlearchive/custom-tabs-provider
# googlearchive/custom-tabs-provider
# googlearchive/datastore-samples
# googlearchive/datastore-samples
# googlearchive/dev-quest
# googlearchive/dev-quest
# googlearchive/dev-video-search
# googlearchive/dev-video-search
# googlearchive/devtools-docs-migration
# googlearchive/devtools-docs-migration
# googlearchive/digitalgoods-sample-php
# googlearchive/digitalgoods-sample-php
# googlearchive/digitalgoods-sample-python
# googlearchive/digitalgoods-sample-python
# googlearchive/drive-crossclientoauth2-android
# googlearchive/drive-crossclientoauth2-android
# googlearchive/drive-dredit
# googlearchive/drive-dredit
# googlearchive/drive-ios-quickeditor
# googlearchive/drive-ios-quickeditor
# googlearchive/firebase-chrome-extension
# googlearchive/firebase-chrome-extension
# googlearchive/fireflicks
# googlearchive/fireflicks
# googlearchive/go-docs-samples
# googlearchive/go-docs-samples
# googlearchive/google-api-dotnet-client-samples
# googlearchive/google-api-dotnet-client-samples
# googlearchive/google-plus-hangout-samples
# googlearchive/google-plus-hangout-samples
# googlearchive/gplus-haiku-client-android
# googlearchive/gplus-haiku-client-android
# googlearchive/gplus-haiku-client-ios
# googlearchive/gplus-haiku-client-ios
# googlearchive/gplus-haiku-server-java
# googlearchive/gplus-haiku-server-java
# googlearchive/gplus-haiku-server-php
# googlearchive/gplus-haiku-server-php
# googlearchive/gplus-verifytoken-python
# googlearchive/gplus-verifytoken-python
# googlearchive/identity-toolkit-android
# googlearchive/identity-toolkit-android
# googlearchive/instantbuy-quickstart-java
# googlearchive/instantbuy-quickstart-java
# googlearchive/instantbuy-quickstart-php
# googlearchive/instantbuy-quickstart-php
# googlearchive/instantbuy-quickstart-ruby
# googlearchive/instantbuy-quickstart-ruby
# googlearchive/instantbuy-sample-csharp
# googlearchive/instantbuy-sample-csharp
# googlearchive/instantbuy-sample-java
# googlearchive/instantbuy-sample-java
# googlearchive/instantbuy-sample-php
# googlearchive/instantbuy-sample-php
# googlearchive/instantbuy-sample-python
# googlearchive/instantbuy-sample-python
# googlearchive/instantbuy-sample-xyz-java
# googlearchive/instantbuy-sample-xyz-java
# googlearchive/interactive-fiction-nodejs
# googlearchive/interactive-fiction-nodejs
# googlearchive/js-v2-samples
# googlearchive/js-v2-samples
# googlearchive/kml-samples
# googlearchive/kml-samples
# googlearchive/leanback-assistant
# googlearchive/leanback-assistant
# googlearchive/leanback-homescreen-channels
# googlearchive/leanback-homescreen-channels
# googlearchive/leanback-showcase
# googlearchive/leanback-showcase
# googlearchive/MobileShoppingAssistant-sample
# googlearchive/MobileShoppingAssistant-sample
# googlearchive/picture-swiper
# googlearchive/picture-swiper
# googlearchive/polymer-patterns
# googlearchive/polymer-patterns
# googlearchive/polyup
# googlearchive/polyup
# googlearchive/sample-framework-boot
# googlearchive/sample-framework-boot
# googlearchive/sample-media-pwa
# googlearchive/sample-media-pwa
# googlearchive/sampler-scaffold
# googlearchive/sampler-scaffold
# googlearchive/samples
# googlearchive/samples
# googlearchive/solutions-apache-hive-and-pig-on-google-compute-engine
# googlearchive/solutions-apache-hive-and-pig-on-google-compute-engine
# googlearchive/storage-appengine-bucket-lister-python
# googlearchive/storage-appengine-bucket-lister-python
# googlearchive/sw-unit-test-sample
# googlearchive/sw-unit-test-sample
# googlearchive/udacity-60fps-samples
# googlearchive/udacity-60fps-samples
# googlearchive/webplatform-samples
# googlearchive/webplatform-samples
